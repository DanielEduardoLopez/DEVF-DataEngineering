# %% [markdown]
# # ¿Qué Recuerdas de la API de Twitter? 😏

# %% [markdown]
# ¡Pongamos a prueba nuestras habilidades para consumir esta API en 4 de sus Endpoints!

# %%
# !pip install tweepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tweepy in /usr/local/lib/python3.7/dist-packages (3.10.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.3.1)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.2.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import itertools
import collections

import tweepy as tw
import nltk
from nltk.corpus import stopwords
import re

# %%
# Si quieres obtener tus propios accesos, puedes hacerlo aquí: https://developer.twitter.com/

ACCESS_TOKEN = '168255741-gPsbVq7Z1y0WV48llvS2zIKhfcgNtzgNUvKb9yId'
# %store ACCESS_TOKEN
ACCESS_TOKEN_SECRET = 'avHdOLnfS55G6GxAhPSRdw7aElGMkQuSDtWGGp5QVTPpL'
# %store ACCESS_TOKEN_SECRET

API_KEY = 'v4vDzeVPX1KHvAknfEQuCERXt'
# %store API_KEY
API_SECRET = 'b4x4dmzAi108pCgBca7cWRjS74X31PMsRE294mZA7C6sGUMSwn'
# %store API_SECRET
# Out:
# Stored 'ACCESS_TOKEN' (str)
# Stored 'ACCESS_TOKEN_SECRET' (str)
# Stored 'API_KEY' (str)
# Stored 'API_SECRET' (str)

# %%
auth = tw.OAuthHandler(API_KEY, API_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tw.API(auth)
api

# %% [markdown]
# ## Tweets de un timeline
#
# - Obtén la timeline de un usuario especifico de Twitter, mostrando solo los primeros 10 tweets
# - Añade los tweets a una lista y conviértelos en un DataFrame

# %%
#documentacion del endpoint https://developer.twitter.com/en/docs/twitter-api/v1/tweets/timelines/api-reference/get-statuses-user_timeline
me_tweets = api.user_timeline(screen_name="@pontifex", count=10)
tweets = []
for tweet in me_tweets:
    print(tweet._json)
    tweets.append(tweet._json)
tweets
tweets_df = pd.DataFrame(tweets)
# Out:
# {'created_at': 'Wed Aug 17 09:30:00 +0000 2022', 'id': 1559834923006980096, 'id_str': '1559834923006980096', 'text': 'The witness of the elderly unites the generations of life. Same with the dimensions of time: past, present and futu… https://t.co/v7qVKgPUH9', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/v7qVKgPUH9', 'expanded_url': 'https://twitter.com/i/web/status/1559834923006980096', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 500704345, 'id_str': '500704345', 'name': 'Pope Francis', 'screen_name': 'Pontifex', 'location': 'Vatican City', 'description': 'Welcome to the official Twitter page of His Holiness Pope Francis', 'url': 'https://t.co/yRhGwps83P', 'entities': {'url': {'urls': [{'url': 'https://t.co/yRhGwps83P', 'expanded_url': 'http://www.vaticannews.va', 'display_url': 'vaticannews.va', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 19001623, 'friends_count': 8, 'listed_count': 24117, 'created_at': 'Thu Feb 23 11:38:07 +0000 2012', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 4281, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/500704345/1409908226', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1288, 'favorite_count': 8146, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Tue Aug 16 11:30:01 +0000 2022', 'id': 1559502736051167234, 'id_str': '1559502736051167234', 'text': 'Love goes beyond usefulness, convenience or duty; love generates wonder, it inspires creative, freely-given zeal.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 500704345, 'id_str': '500704345', 'name': 'Pope Francis', 'screen_name': 'Pontifex', 'location': 'Vatican City', 'description': 'Welcome to the official Twitter page of His Holiness Pope Francis', 'url': 'https://t.co/yRhGwps83P', 'entities': {'url': {'urls': [{'url': 'https://t.co/yRhGwps83P', 'expanded_url': 'http://www.vaticannews.va', 'display_url': 'vaticannews.va', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 19001623, 'friends_count': 8, 'listed_count': 24117, 'created_at': 'Thu Feb 23 11:38:07 +0000 2012', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 4281, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/500704345/1409908226', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 2725, 'favorite_count': 16467, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Mon Aug 15 12:00:00 +0000 2022', 'id': 1559147895416188929, 'id_str': '1559147895416188929', 'text': 'Let us continue to invoke the intercession of Our Lady, so that God might give the world peace, and let us pray in… https://t.co/bU2ncb6T2G', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/bU2ncb6T2G', 'expanded_url': 'https://twitter.com/i/web/status/1559147895416188929', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 500704345, 'id_str': '500704345', 'name': 'Pope Francis', 'screen_name': 'Pontifex', 'location': 'Vatican City', 'description': 'Welcome to the official Twitter page of His Holiness Pope Francis', 'url': 'https://t.co/yRhGwps83P', 'entities': {'url': {'urls': [{'url': 'https://t.co/yRhGwps83P', 'expanded_url': 'http://www.vaticannews.va', 'display_url': 'vaticannews.va', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 19001623, 'friends_count': 8, 'listed_count': 24117, 'created_at': 'Thu Feb 23 11:38:07 +0000 2012', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 4281, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/500704345/1409908226', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1743, 'favorite_count': 13955, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Mon Aug 15 10:30:00 +0000 2022', 'id': 1559125246027915264, 'id_str': '1559125246027915264', 'text': 'Looking at the Mother of God in glory, we understand that true power is service, that to reign means to love, and t… https://t.co/8ECdMzoMyC', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/8ECdMzoMyC', 'expanded_url': 'https://twitter.com/i/web/status/1559125246027915264', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 500704345, 'id_str': '500704345', 'name': 'Pope Francis', 'screen_name': 'Pontifex', 'location': 'Vatican City', 'description': 'Welcome to the official Twitter page of His Holiness Pope Francis', 'url': 'https://t.co/yRhGwps83P', 'entities': {'url': {'urls': [{'url': 'https://t.co/yRhGwps83P', 'expanded_url': 'http://www.vaticannews.va', 'display_url': 'vaticannews.va', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 19001623, 'friends_count': 8, 'listed_count': 24117, 'created_at': 'Thu Feb 23 11:38:07 +0000 2012', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 4281, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/500704345/1409908226', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1984, 'favorite_count': 13025, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Aug 14 15:00:01 +0000 2022', 'id': 1558830810177880069, 'id_str': '1558830810177880069', 'text': 'The populations of Somalia and various zones of the neighbouring countries, who already live in very precarious con… https://t.co/fWSlj7yuQ4', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/fWSlj7yuQ4', 'expanded_url': 'https://twitter.com/i/web/status/1558830810177880069', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 500704345, 'id_str': '500704345', 'name': 'Pope Francis', 'screen_name': 'Pontifex', 'location': 'Vatican City', 'description': 'Welcome to the official Twitter page of His Holiness Pope Francis', 'url': 'https://t.co/yRhGwps83P', 'entities': {'url': {'urls': [{'url': 'https://t.co/yRhGwps83P', 'expanded_url': 'http://www.vaticannews.va', 'display_url': 'vaticannews.va', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 19001623, 'friends_count': 8, 'listed_count': 24117, 'created_at': 'Thu Feb 23 11:38:07 +0000 2012', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 4281, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/500704345/1409908226', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1213, 'favorite_count': 7913, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Aug 14 10:30:00 +0000 2022', 'id': 1558762859831537665, 'id_str': '1558762859831537665', 'text': 'The Gospel sets us in motion, and drives us to open up to God and our brothers. It is just like fire: while it warm… https://t.co/Le5bWrYnET', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Le5bWrYnET', 'expanded_url': 'https://twitter.com/i/web/status/1558762859831537665', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 500704345, 'id_str': '500704345', 'name': 'Pope Francis', 'screen_name': 'Pontifex', 'location': 'Vatican City', 'description': 'Welcome to the official Twitter page of His Holiness Pope Francis', 'url': 'https://t.co/yRhGwps83P', 'entities': {'url': {'urls': [{'url': 'https://t.co/yRhGwps83P', 'expanded_url': 'http://www.vaticannews.va', 'display_url': 'vaticannews.va', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 19001623, 'friends_count': 8, 'listed_count': 24117, 'created_at': 'Thu Feb 23 11:38:07 +0000 2012', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 4281, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/500704345/1409908226', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1735, 'favorite_count': 11111, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sat Aug 13 11:30:00 +0000 2022', 'id': 1558415568843071488, 'id_str': '1558415568843071488', 'text': 'We need to pray always, even when everything seems in vain, when God appears to be deaf and mute and it seems we ar… https://t.co/aNeyXPa1lm', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/aNeyXPa1lm', 'expanded_url': 'https://twitter.com/i/web/status/1558415568843071488', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 500704345, 'id_str': '500704345', 'name': 'Pope Francis', 'screen_name': 'Pontifex', 'location': 'Vatican City', 'description': 'Welcome to the official Twitter page of His Holiness Pope Francis', 'url': 'https://t.co/yRhGwps83P', 'entities': {'url': {'urls': [{'url': 'https://t.co/yRhGwps83P', 'expanded_url': 'http://www.vaticannews.va', 'display_url': 'vaticannews.va', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 19001623, 'friends_count': 8, 'listed_count': 24117, 'created_at': 'Thu Feb 23 11:38:07 +0000 2012', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 4281, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/500704345/1409908226', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 3853, 'favorite_count': 24652, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Fri Aug 12 11:30:00 +0000 2022', 'id': 1558053183422976000, 'id_str': '1558053183422976000', 'text': 'We are unique, free and alive, called to live a love story with God, to make bold and firm decisions, to accept the… https://t.co/NeUZ5VBN9N', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/NeUZ5VBN9N', 'expanded_url': 'https://twitter.com/i/web/status/1558053183422976000', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 500704345, 'id_str': '500704345', 'name': 'Pope Francis', 'screen_name': 'Pontifex', 'location': 'Vatican City', 'description': 'Welcome to the official Twitter page of His Holiness Pope Francis', 'url': 'https://t.co/yRhGwps83P', 'entities': {'url': {'urls': [{'url': 'https://t.co/yRhGwps83P', 'expanded_url': 'http://www.vaticannews.va', 'display_url': 'vaticannews.va', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 19001623, 'friends_count': 8, 'listed_count': 24117, 'created_at': 'Thu Feb 23 11:38:07 +0000 2012', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 4281, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/500704345/1409908226', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 2720, 'favorite_count': 18109, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Thu Aug 11 11:30:00 +0000 2022', 'id': 1557690794839986176, 'id_str': '1557690794839986176', 'text': 'Those who believe themselves to be rich, successful and secure, base everything on themselves and close themselves… https://t.co/HQkuXiM4u6', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/HQkuXiM4u6', 'expanded_url': 'https://twitter.com/i/web/status/1557690794839986176', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 500704345, 'id_str': '500704345', 'name': 'Pope Francis', 'screen_name': 'Pontifex', 'location': 'Vatican City', 'description': 'Welcome to the official Twitter page of His Holiness Pope Francis', 'url': 'https://t.co/yRhGwps83P', 'entities': {'url': {'urls': [{'url': 'https://t.co/yRhGwps83P', 'expanded_url': 'http://www.vaticannews.va', 'display_url': 'vaticannews.va', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 19001623, 'friends_count': 8, 'listed_count': 24117, 'created_at': 'Thu Feb 23 11:38:07 +0000 2012', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 4281, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/500704345/1409908226', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 2230, 'favorite_count': 14664, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Wed Aug 10 11:30:00 +0000 2022', 'id': 1557328405338542081, 'id_str': '1557328405338542081', 'text': 'Old age is the phase in life most suited to spreading the joyful news that life is the initiation to a final fulfil… https://t.co/33GOGdNTxV', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/33GOGdNTxV', 'expanded_url': 'https://twitter.com/i/web/status/1557328405338542081', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 500704345, 'id_str': '500704345', 'name': 'Pope Francis', 'screen_name': 'Pontifex', 'location': 'Vatican City', 'description': 'Welcome to the official Twitter page of His Holiness Pope Francis', 'url': 'https://t.co/yRhGwps83P', 'entities': {'url': {'urls': [{'url': 'https://t.co/yRhGwps83P', 'expanded_url': 'http://www.vaticannews.va', 'display_url': 'vaticannews.va', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 19001623, 'friends_count': 8, 'listed_count': 24117, 'created_at': 'Thu Feb 23 11:38:07 +0000 2012', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 4281, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/507818066814590976/KNG-IkT9_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/500704345/1409908226', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 2314, 'favorite_count': 17740, 'favorited': False, 'retweeted': False, 'lang': 'en'}

# %%
tweets_df
# Out:
#                        created_at                   id               id_str  \
# 0  Wed Aug 17 09:30:00 +0000 2022  1559834923006980096  1559834923006980096
# 1  Tue Aug 16 11:30:01 +0000 2022  1559502736051167234  1559502736051167234
# 2  Mon Aug 15 12:00:00 +0000 2022  1559147895416188929  1559147895416188929
# 3  Mon Aug 15 10:30:00 +0000 2022  1559125246027915264  1559125246027915264
# 4  Sun Aug 14 15:00:01 +0000 2022  1558830810177880069  1558830810177880069
# 5  Sun Aug 14 10:30:00 +0000 2022  1558762859831537665  1558762859831537665
# 6  Sat Aug 13 11:30:00 +0000 2022  1558415568843071488  1558415568843071488
# 7  Fri Aug 12 11:30:00 +0000 2022  1558053183422976000  1558053183422976000
# 8  Thu Aug 11 11:30:00 +0000 2022  1557690794839986176  1557690794839986176
# 9  Wed Aug 10 11:30:00 +0000 2022  1557328405338542081  1557328405338542081
#
#                                                 text  truncated  \
# 0  The witness of the elderly unites the generati...       True
# 1  Love goes beyond usefulness, convenience or du...      False
# 2  Let us continue to invoke the intercession of ...       True
# 3  Looking at the Mother of God in glory, we unde...       True
# 4  The populations of Somalia and various zones o...       True
# 5  The Gospel sets us in motion, and drives us to...       True
# 6  We need to pray always, even when everything s...       True
# 7  We are unique, free and alive, called to live ...       True
# 8  Those who believe themselves to be rich, succe...       True
# 9  Old age is the phase in life most suited to sp...       True
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...
# 5  {'hashtags': [], 'symbols': [], 'user_mentions...
# 6  {'hashtags': [], 'symbols': [], 'user_mentions...
# 7  {'hashtags': [], 'symbols': [], 'user_mentions...
# 8  {'hashtags': [], 'symbols': [], 'user_mentions...
# 9  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                               source in_reply_to_status_id  \
# 0  <a href="https://about.twitter.com/products/tw...                  None
# 1  <a href="https://about.twitter.com/products/tw...                  None
# 2  <a href="https://about.twitter.com/products/tw...                  None
# 3  <a href="https://about.twitter.com/products/tw...                  None
# 4  <a href="https://about.twitter.com/products/tw...                  None
# 5  <a href="https://about.twitter.com/products/tw...                  None
# 6  <a href="https://about.twitter.com/products/tw...                  None
# 7  <a href="https://about.twitter.com/products/tw...                  None
# 8  <a href="https://about.twitter.com/products/tw...                  None
# 9  <a href="https://about.twitter.com/products/tw...                  None
#
#   in_reply_to_status_id_str in_reply_to_user_id  ...   geo coordinates place  \
# 0                      None                None  ...  None        None  None
# 1                      None                None  ...  None        None  None
# 2                      None                None  ...  None        None  None
# 3                      None                None  ...  None        None  None
# 4                      None                None  ...  None        None  None
# 5                      None                None  ...  None        None  None
# 6                      None                None  ...  None        None  None
# 7                      None                None  ...  None        None  None
# 8                      None                None  ...  None        None  None
# 9                      None                None  ...  None        None  None
#
#   contributors is_quote_status retweet_count favorite_count  favorited  \
# 0         None           False          1288           8146      False
# 1         None           False          2725          16467      False
# 2         None           False          1743          13955      False
# 3         None           False          1984          13025      False
# 4         None           False          1213           7913      False
# 5         None           False          1735          11111      False
# 6         None           False          3853          24652      False
# 7         None           False          2720          18109      False
# 8         None           False          2230          14664      False
# 9         None           False          2314          17740      False
#
#    retweeted  lang
# 0      False    en
# 1      False    en
# 2      False    en
# 3      False    en
# 4      False    en
# 5      False    en
# 6      False    en
# 7      False    en
# 8      False    en
# 9      False    en
#
# [10 rows x 23 columns]

# %% [markdown]
# ## Tweets del home
#
# - Obtén de la timeline del home de Twitter, solo los primeros 10 tweets
# - Añade los tweets a una lista y conviértelos en un DataFrame

# %%
#documentacion del endpoint https://developer.twitter.com/en/docs/twitter-api/v1/tweets/timelines/api-reference/get-statuses-home_timeline
#home_timeline

# %%
public_tweets = api.home_timeline(count=10)
holi = []
for tweet in public_tweets:
    print(tweet._json)
    holi.append(tweet._json)
holi
pd.DataFrame(holi)
# Out:
# {'created_at': 'Thu Aug 18 01:56:00 +0000 2022', 'id': 1560083058489004032, 'id_str': '1560083058489004032', 'text': '😢¡Lo vamos a extrañar! Jonah Hill anunció que se alejará de los reflectores para trabajar en su salud mental. 👇 \nhttps://t.co/JOSMSvjuVI', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/JOSMSvjuVI', 'expanded_url': 'https://www.sopitas.com/cine-y-tv/jonah-hill-anuncia-dejara-promocionar-peliculas-problemas-salud-mental-ansiedad/', 'display_url': 'sopitas.com/cine-y-tv/jona…', 'indices': [113, 136]}]}, 'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3362741, 'id_str': '3362741', 'name': 'Sopitas', 'screen_name': 'sopitas', 'location': 'Mexico', 'description': '¡Un tipo muy afortunado!\n\nContacto: sopitas@sopitas.com', 'url': 'https://t.co/fCwfsZCHzT', 'entities': {'url': {'urls': [{'url': 'https://t.co/fCwfsZCHzT', 'expanded_url': 'http://www.sopitas.com', 'display_url': 'sopitas.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 3237245, 'friends_count': 3577, 'listed_count': 6081, 'created_at': 'Tue Apr 03 21:18:19 +0000 2007', 'favourites_count': 6955, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 260484, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '9AE4E8', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1066360955917881344/1JEzA5He_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1066360955917881344/1JEzA5He_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3362741/1643673509', 'profile_link_color': '0000FF', 'profile_sidebar_border_color': '87BC44', 'profile_sidebar_fill_color': 'E0FF92', 'profile_text_color': '000000', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'es'}
# {'created_at': 'Thu Aug 18 01:55:13 +0000 2022', 'id': 1560082861201494016, 'id_str': '1560082861201494016', 'text': '▶️ Fiscalía de #Nayarit prepara estrategia jurídica para buscar extradición de Édgar Veytia de #EU\n\nAquí nos inform… https://t.co/SvF9N65VF1', 'truncated': True, 'entities': {'hashtags': [{'text': 'Nayarit', 'indices': [15, 23]}, {'text': 'EU', 'indices': [95, 98]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/SvF9N65VF1', 'expanded_url': 'https://twitter.com/i/web/status/1560082861201494016', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://www.twitter.com/" rel="nofollow">Twitter Media Studio - LiveCut</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 24969337, 'id_str': '24969337', 'name': 'Milenio', 'screen_name': 'Milenio', 'location': 'México', 'description': '#M1lenio', 'url': 'https://t.co/LsGjQVCpU3', 'entities': {'url': {'urls': [{'url': 'https://t.co/LsGjQVCpU3', 'expanded_url': 'http://www.milenio.com', 'display_url': 'milenio.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 5469988, 'friends_count': 0, 'listed_count': 15675, 'created_at': 'Tue Mar 17 22:26:38 +0000 2009', 'favourites_count': 6, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 1111351, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': 'EBEBEB', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme3/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme3/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1493329155630448644/8XwrlJJw_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1493329155630448644/8XwrlJJw_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/24969337/1657663238', 'profile_link_color': 'AB0303', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F3F3F3', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'es'}
# {'created_at': 'Thu Aug 18 01:55:13 +0000 2022', 'id': 1560082858697449475, 'id_str': '1560082858697449475', 'text': 'The Reluctant Prophet of Effective Altruism | The New Yorker https://t.co/ojDVB3gqhK', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/ojDVB3gqhK', 'expanded_url': 'https://www.newyorker.com/magazine/2022/08/15/the-reluctant-prophet-of-effective-altruism', 'display_url': 'newyorker.com/magazine/2022/…', 'indices': [61, 84]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 18408506, 'id_str': '18408506', 'name': 'Leon Palafox', 'screen_name': 'leonpalafox', 'location': 'Coyoacán, Distrito Federal', 'description': '🌐 🎓#MachineLearning Director at @algorithia | PhD and MsC from @UTokyo_News | #AI Professor at @UPMexico | Opinion writer at @ElFinanciero_Mx', 'url': 'https://t.co/0qmI4tufDO', 'entities': {'url': {'urls': [{'url': 'https://t.co/0qmI4tufDO', 'expanded_url': 'https://leonpalafox.github.io/', 'display_url': 'leonpalafox.github.io', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 2656, 'friends_count': 1786, 'listed_count': 90, 'created_at': 'Sat Dec 27 14:36:27 +0000 2008', 'favourites_count': 1211, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 17990, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '131516', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1094374315326402561/JRUlkmLf_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1094374315326402561/JRUlkmLf_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18408506/1623652083', 'profile_link_color': 'ABB8C2', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}
# {'created_at': 'Thu Aug 18 01:55:02 +0000 2022', 'id': 1560082814732746752, 'id_str': '1560082814732746752', 'text': '¿Te pondrías un refuerzo de la vacuna de covid-19? Epidemiólogo te aconseja que lo hagas este otoño boreal… https://t.co/LWP92Ugh4V', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/LWP92Ugh4V', 'expanded_url': 'https://twitter.com/i/web/status/1560082814732746752', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [108, 131]}]}, 'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 33884545, 'id_str': '33884545', 'name': 'CNN en Español', 'screen_name': 'CNNEE', 'location': 'En todas partes', 'description': 'CNN en Español es tu principal fuente de información y breaking news. Cubrimos las noticias de América Latina y el resto del mundo. Vive la noticia.', 'url': 'https://t.co/6nHDD785lT', 'entities': {'url': {'urls': [{'url': 'https://t.co/6nHDD785lT', 'expanded_url': 'http://cnnespanol.cnn.com', 'display_url': 'cnnespanol.cnn.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 22018329, 'friends_count': 413, 'listed_count': 52600, 'created_at': 'Tue Apr 21 12:14:47 +0000 2009', 'favourites_count': 1498, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 381630, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1504512864123600897/aBxxzqgm_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1504512864123600897/aBxxzqgm_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/33884545/1411070627', 'profile_link_color': 'AB1529', 'profile_sidebar_border_color': 'B5B5B5', 'profile_sidebar_fill_color': 'B5B5B5', 'profile_text_color': '000000', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 5, 'favorite_count': 9, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'es'}
# {'created_at': 'Thu Aug 18 01:54:43 +0000 2022', 'id': 1560082735884279808, 'id_str': '1560082735884279808', 'text': 'Abucheos, gestos racistas, una salida del escenario entre guardias de seguridad y 85 millones de espectadores viend… https://t.co/HzAn6dW53t', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/HzAn6dW53t', 'expanded_url': 'https://twitter.com/i/web/status/1560082735884279808', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 10012122, 'id_str': '10012122', 'name': 'BBC News Mundo', 'screen_name': 'bbcmundo', 'location': 'Londres, Inglaterra.', 'description': 'Twitter oficial de BBC News Mundo. Aquí encuentran una selección de lo mejor de nuestro contenido y los invitamos a una conversación global. ¿Se animan?', 'url': 'https://t.co/iLpzpfBEWb', 'entities': {'url': {'urls': [{'url': 'https://t.co/iLpzpfBEWb', 'expanded_url': 'http://www.bbcmundo.com', 'display_url': 'bbcmundo.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 4923102, 'friends_count': 438, 'listed_count': 22872, 'created_at': 'Tue Nov 06 21:50:06 +0000 2007', 'favourites_count': 969, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 420855, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1001752869517910016/Xq8-sAa4_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1001752869517910016/Xq8-sAa4_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/10012122/1628850476', 'profile_link_color': '003366', 'profile_sidebar_border_color': 'C2C2C2', 'profile_sidebar_fill_color': 'E8E8E8', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 7, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'es'}
# {'created_at': 'Thu Aug 18 01:54:33 +0000 2022', 'id': 1560082691231449094, 'id_str': '1560082691231449094', 'text': 'RT @laaficion: LeBron James renueva con Lakers para poder jugar con su hijo antes del retiro: reportes\n\nhttps://t.co/96uXI1ueHj https://t.c…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'laaficion', 'name': 'La Afición', 'id': 21711729, 'id_str': '21711729', 'indices': [3, 13]}], 'urls': [{'url': 'https://t.co/96uXI1ueHj', 'expanded_url': 'https://mile.io/3QM6zUw', 'display_url': 'mile.io/3QM6zUw', 'indices': [104, 127]}]}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 24969337, 'id_str': '24969337', 'name': 'Milenio', 'screen_name': 'Milenio', 'location': 'México', 'description': '#M1lenio', 'url': 'https://t.co/LsGjQVCpU3', 'entities': {'url': {'urls': [{'url': 'https://t.co/LsGjQVCpU3', 'expanded_url': 'http://www.milenio.com', 'display_url': 'milenio.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 5469988, 'friends_count': 0, 'listed_count': 15675, 'created_at': 'Tue Mar 17 22:26:38 +0000 2009', 'favourites_count': 6, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 1111351, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': 'EBEBEB', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme3/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme3/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1493329155630448644/8XwrlJJw_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1493329155630448644/8XwrlJJw_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/24969337/1657663238', 'profile_link_color': 'AB0303', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F3F3F3', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Aug 18 01:50:03 +0000 2022', 'id': 1560081560224800770, 'id_str': '1560081560224800770', 'text': 'LeBron James renueva con Lakers para poder jugar con su hijo antes del retiro: reportes\n\nhttps://t.co/96uXI1ueHj https://t.co/LCtmEJ5dnA', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/96uXI1ueHj', 'expanded_url': 'https://mile.io/3QM6zUw', 'display_url': 'mile.io/3QM6zUw', 'indices': [89, 112]}], 'media': [{'id': 1560081533549117440, 'id_str': '1560081533549117440', 'indices': [113, 136], 'media_url': 'http://pbs.twimg.com/media/FaaF45vXgAAXKxv.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FaaF45vXgAAXKxv.jpg', 'url': 'https://t.co/LCtmEJ5dnA', 'display_url': 'pic.twitter.com/LCtmEJ5dnA', 'expanded_url': 'https://twitter.com/laaficion/status/1560081560224800770/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1200, 'h': 747, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 747, 'resize': 'fit'}, 'small': {'w': 680, 'h': 423, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1560081533549117440, 'id_str': '1560081533549117440', 'indices': [113, 136], 'media_url': 'http://pbs.twimg.com/media/FaaF45vXgAAXKxv.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FaaF45vXgAAXKxv.jpg', 'url': 'https://t.co ...
# {'created_at': 'Thu Aug 18 01:54:06 +0000 2022', 'id': 1560082579759534080, 'id_str': '1560082579759534080', 'text': 'Reunificar completa a la patria, tendencia irresistible: Zhu Qingqiao, embajador de China en México\n\nhttps://t.co/CFwrWQbOkA', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/CFwrWQbOkA', 'expanded_url': 'https://www.eleconomista.com.mx/internacionales/Reunificar-completa-a-la-patria-tendencia-irresistible-Zhu-Qingqiao-embajador-de-China-en-Mexico-20220817-0116.html', 'display_url': 'eleconomista.com.mx/internacionale…', 'indices': [101, 124]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 14917589, 'id_str': '14917589', 'name': 'El Economista', 'screen_name': 'eleconomista', 'location': 'México, DF', 'description': 'Somos el diario económico, financiero y de negocios de México, fundado en 1988. Hablamos con los profesionales.', 'url': 'https://t.co/7vF0wtKTub', 'entities': {'url': {'urls': [{'url': 'https://t.co/7vF0wtKTub', 'expanded_url': 'http://eleconomista.com.mx', 'display_url': 'eleconomista.com.mx', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 871971, 'friends_count': 107, 'listed_count': 5220, 'created_at': 'Tue May 27 06:07:11 +0000 2008', 'favourites_count': 5011, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 548784, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C4DBE1', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1541490430621229065/v3LQaZer_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1541490430621229065/v3LQaZer_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14917589/1656354934', 'profile_link_color': '006595', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '66CCFF', 'profile_text_color': '666666', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'ca'}
# {'created_at': 'Thu Aug 18 01:54:05 +0000 2022', 'id': 1560082576160616449, 'id_str': '1560082576160616449', 'text': 'SISMO Magnitud 4.0 Loc  4 km al NORESTE de JUAN MORALES, MOR 17/08/22 20:35:44 Lat 18.84 Lon -98.90 Pf 6 km https://t.co/pIKPivrsOR', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1560082575275671552, 'id_str': '1560082575275671552', 'indices': [108, 131], 'media_url': 'http://pbs.twimg.com/media/FaaG1ieVQAAyapq.png', 'media_url_https': 'https://pbs.twimg.com/media/FaaG1ieVQAAyapq.png', 'url': 'https://t.co/pIKPivrsOR', 'display_url': 'pic.twitter.com/pIKPivrsOR', 'expanded_url': 'https://twitter.com/SismologicoMX/status/1560082576160616449/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 500, 'h': 300, 'resize': 'fit'}, 'medium': {'w': 500, 'h': 300, 'resize': 'fit'}, 'large': {'w': 500, 'h': 300, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]}, 'extended_entities': {'media': [{'id': 1560082575275671552, 'id_str': '1560082575275671552', 'indices': [108, 131], 'media_url': 'http://pbs.twimg.com/media/FaaG1ieVQAAyapq.png', 'media_url_https': 'https://pbs.twimg.com/media/FaaG1ieVQAAyapq.png', 'url': 'https://t.co/pIKPivrsOR', 'display_url': 'pic.twitter.com/pIKPivrsOR', 'expanded_url': 'https://twitter.com/SismologicoMX/status/1560082576160616449/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 500, 'h': 300, 'resize': 'fit'}, 'medium': {'w': 500, 'h': 300, 'resize': 'fit'}, 'large': {'w': 500, 'h': 300, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]}, 'source': '<a href="http://www.sismologico.unam..mx" rel="nofollow">tweetSismologicoMx</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 44923719, 'id_str': '44923719', 'name': 'Sismologico Nacional', 'screen_name': 'SismologicoMX', 'location': 'Ciudad Universitaria, CDMX', 'description': 'El Servicio Sismológico Nacional fue fundado el 5/Sep/1910. Forma parte de la @UNAM_MX desde 1929. Su misión es informar sobre la actividad sísmica en México.', 'url': 'https://t.co/zfq5Ohppk4', 'entities': {'url': {'urls': [{'url': 'https://t.co/zfq5Ohppk4', 'expanded_url': 'http://www.ssn.unam.mx', 'display_url': 'ssn.unam.mx', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 4915913, 'friends_count': 0, 'listed_count': 6852, 'created_at': 'Fri Jun 05 16:00:29 +0000 2009', 'favourites_count': 14, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 226426, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1544109088648450053/_rB8mHEG_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1544109088648450053/_rB8mHEG_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44923719/1535849647', 'profile_link_color': '003A73', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 5, 'favorite_count': 15, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'es'}
# {'created_at': 'Thu Aug 18 01:54:01 +0000 2022', 'id': 1560082560289370112, 'id_str': '1560082560289370112', 'text': 'SISMO Magnitud 4.0 Loc. 4 km al NORESTE de JUAN MORALES, MOR 17/08/22 20:35:44 Lat 18.84 Lon -98.90 Pf 6 km', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://www.sismologico.unam..mx" rel="nofollow">tweetSismologicoMx</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 44923719, 'id_str': '44923719', 'name': 'Sismologico Nacional', 'screen_name': 'SismologicoMX', 'location': 'Ciudad Universitaria, CDMX', 'description': 'El Servicio Sismológico Nacional fue fundado el 5/Sep/1910. Forma parte de la @UNAM_MX desde 1929. Su misión es informar sobre la actividad sísmica en México.', 'url': 'https://t.co/zfq5Ohppk4', 'entities': {'url': {'urls': [{'url': 'https://t.co/zfq5Ohppk4', 'expanded_url': 'http://www.ssn.unam.mx', 'display_url': 'ssn.unam.mx', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 4915913, 'friends_count': 0, 'listed_count': 6852, 'created_at': 'Fri Jun 05 16:00:29 +0000 2009', 'favourites_count': 14, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 226426, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1544109088648450053/_rB8mHEG_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1544109088648450053/_rB8mHEG_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44923719/1535849647', 'profile_link_color': '003A73', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 13, 'favorited': False, 'retweeted': False, 'lang': 'es'}
# {'created_at': 'Thu Aug 18 01:52:51 +0000 2022', 'id': 1560082263643226112, 'id_str': '1560082263643226112', 'text': 'RT @INDlRECTAZ: https://t.co/uQDLmfJ2TH', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'INDlRECTAZ', 'name': '𝕀ℕ𝔻𝕀ℝ𝔼ℂ𝕋𝔸ℤ ✨', 'id': 1473798169989459976, 'id_str': '1473798169989459976', 'indices': [3, 14]}], 'urls': [], 'media': [{'id': 1560082172870115330, 'id_str': '1560082172870115330', 'indices': [16, 39], 'media_url': 'http://pbs.twimg.com/media/FaaGeHZXwAIa7nI.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FaaGeHZXwAIa7nI.jpg', 'url': 'https://t.co/uQDLmfJ2TH', 'display_url': 'pic.twitter.com/uQDLmfJ2TH', 'expanded_url': 'https://twitter.com/INDlRECTAZ/status/1560082177722929152/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 674, 'resize': 'fit'}, 'medium': {'w': 1125, 'h': 1115, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1125, 'h': 1115, 'resize': 'fit'}}, 'source_status_id': 1560082177722929152, 'source_status_id_str': '1560082177722929152', 'source_user_id': 1473798169989459976, 'source_user_id_str': '1473798169989459976'}]}, 'extended_entities': {'media': [{'id': 1560082172870115330, 'id_str': '1560082172870115330', 'indices': [16, 39], 'media_url': 'http://pbs.twimg.com/media/FaaGeHZXwAIa7nI.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FaaGeHZXwAIa7nI.jpg', 'url': 'https://t.co/uQDLmfJ2TH', 'display_url': 'pic.twitter.com/uQDLmfJ2TH', 'expanded_url': 'https://twitter.com/INDlRECTAZ/status/1560082177722929152/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 674, 'resize': 'fit'}, 'medium': {'w': 1125, 'h': 1115, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1125, 'h': 1115, 'resize': 'fit'}}, 'source_status_id': 1560082177722929152, 'source_status_id_str': '1560082177722929152', 'source_user_id': 1473798169989459976, 'source_user_id_str': '1473798169989459976'}]}, 'source': '<a href="https://www.twitter.com" rel="nofollow">Bugatti (2)</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 964565330, 'id_str': '964565330', 'name': 'Politécnico', 'screen_name': 'polituitts', 'location': 'Nezahualcóyotl, México', 'description': 'Tuitero de tiempo completo y data scientist en mis ratos libres.', 'url': 'https://t.co/jfM1ZmUq7w', 'entities': {'url': {'urls': [{'url': 'https://t.co/jfM1ZmUq7w', 'expanded_url': 'http://Instagram.com/actitud_ipn', 'display_url': 'Instagram.com/actitud_ipn', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 336931, 'friends_count': 363, 'listed_count': 224, 'created_at': 'Thu Nov 22 16:37:39 +0000 2012', 'favourites_count': 20063, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 20859, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1551764825998589953/isGjcVnm_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1551764825998589953/isGjcVnm_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/964565330/1660247044', 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'E6F6F9', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular', 'withheld_in ...
#                        created_at                   id               id_str  \
# 0  Thu Aug 18 01:56:00 +0000 2022  1560083058489004032  1560083058489004032
# 1  Thu Aug 18 01:55:13 +0000 2022  1560082861201494016  1560082861201494016
# 2  Thu Aug 18 01:55:13 +0000 2022  1560082858697449475  1560082858697449475
# 3  Thu Aug 18 01:55:02 +0000 2022  1560082814732746752  1560082814732746752
# 4  Thu Aug 18 01:54:43 +0000 2022  1560082735884279808  1560082735884279808
# 5  Thu Aug 18 01:54:33 +0000 2022  1560082691231449094  1560082691231449094
# 6  Thu Aug 18 01:54:06 +0000 2022  1560082579759534080  1560082579759534080
# 7  Thu Aug 18 01:54:05 +0000 2022  1560082576160616449  1560082576160616449
# 8  Thu Aug 18 01:54:01 +0000 2022  1560082560289370112  1560082560289370112
# 9  Thu Aug 18 01:52:51 +0000 2022  1560082263643226112  1560082263643226112
#
#                                                 text  truncated  \
# 0  😢¡Lo vamos a extrañar! Jonah Hill anunció que ...      False
# 1  ▶️ Fiscalía de #Nayarit prepara estrategia jur...       True
# 2  The Reluctant Prophet of Effective Altruism | ...      False
# 3  ¿Te pondrías un refuerzo de la vacuna de covid...       True
# 4  Abucheos, gestos racistas, una salida del esce...       True
# 5  RT @laaficion: LeBron James renueva con Lakers...      False
# 6  Reunificar completa a la patria, tendencia irr...      False
# 7  SISMO Magnitud 4.0 Loc  4 km al NORESTE de JUA...      False
# 8  SISMO Magnitud 4.0 Loc. 4 km al NORESTE de JUA...      False
# 9            RT @INDlRECTAZ: https://t.co/uQDLmfJ2TH      False
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [{'text': 'Nayarit', 'indices': [...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...
# 5  {'hashtags': [], 'symbols': [], 'user_mentions...
# 6  {'hashtags': [], 'symbols': [], 'user_mentions...
# 7  {'hashtags': [], 'symbols': [], 'user_mentions...
# 8  {'hashtags': [], 'symbols': [], 'user_mentions...
# 9  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                               source in_reply_to_status_id  \
# 0  <a href="https://buffer.com" rel="nofollow">Bu...                  None
# 1  <a href="https://www.twitter.com/" rel="nofoll...                  None
# 2  <a href="http://twitter.com/download/iphone" r...                  None
# 3  <a href="http://www.socialflow.com" rel="nofol...                  None
# 4  <a href="http://www.socialflow.com" rel="nofol...                  None
# 5  <a href="https://about.twitter.com/products/tw...                  None
# 6  <a href="http://twitter.com/download/iphone" r...                  None
# 7  <a href="http://www.sismologico.unam..mx" rel=...                  None
# 8  <a href="http://www.sismologico.unam..mx" rel=...                  None
# 9  <a href="https://www.twitter.com" rel="nofollo...                  None
#
#   in_reply_to_status_id_str in_reply_to_user_id  ... is_quote_status  \
# 0                      None                None  ...           False
# 1                      None                None  ...           False
# 2                      None                None  ...           False
# 3                      None                None  ...           False
# 4                      None                None  ...           False
# 5                      None                None  ...           False
# 6                      None                None  ...           False
# 7                      None                None  ...           False
# 8                      None                None  ...           False
# 9                      None                None  ...           False
#
#   retweet_count favorite_count favorited retweeted possibly_sensitive  \
# 0             0              0     False     False              False
# 1             1              0     False     False              False
# 2             0              0     False     False              False
# 3             5              9     False     False              False
# 4             1              7     False     False              False
# 5             4              0     False     False              False
# 6             0              0     False     False              False
# 7             5             15     False     False              False
# 8             1             13     False     False                NaN
# 9            47              0     False     False              False
#
#   possibly_sensitive_appealable  lang  \
# 0                         False    es
# 1                         False    es
# 2                         False    en
# 3                         False    es
# 4                         False    es
# 5                         False    es
# 6                         False    ca
# 7                         False    es
# 8                           NaN    es
# 9                         False   zxx
#
#                                     retweeted_status  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  {'created_at': 'Thu Aug 18 01:50:03 +0000 2022...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  {'created_at': 'Thu Aug 18 01:52:30 +0000 2022...
#
#                                    extended_entities
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  {'media': [{'id': 1560082575275671552, 'id_str...
# 8                                                NaN
# 9  {'media': [{'id': 1560082172870115330, 'id_str...
#
# [10 rows x 27 columns]

# %% [markdown]
# ## Mentions del timeline
#
# - Obtén las 20 menciones mas recientes.
# - Añade los tweets a una lista y conviértelos en un DataFrame

# %%
#documentacion del endpoint https://developer.twitter.com/en/docs/twitter-api/v1/tweets/timelines/api-reference/get-statuses-mentions_timeline
#mentions_timeline

# %%
search_term = "#pope+francis -filter:retweets"

tweets = tw.Cursor(api.search,
                   q=search_term,
                   lang="en",
                   start_time='2022-08-17',).items(20)

all_tweets = [tweet.text for tweet in tweets]

pd.DataFrame(all_tweets)
# Out:
#                                                     0
# 0   #Pope Francis continues his series of talks on...
# 1   Before my private audience with #Pope Francis ...
# 2   “The image of a God, who is watching over ever...
# 3   😱Pope Francis &amp; the Omega Point???\n\nExpo...
# 4   This Atheist Begs You to Read the Pope’s New B...
# 5   SEDE-VACANTE! (Since October 9, 1958)\nCMRI’s ...
# 6   VACANCY OF THE HOLY SEE! (since October 9, 195...
# 7   Voice of America - #Pope #Francis said that th...
# 8   😱Pope Francis &amp; the Omega Point???\n\nExpo...
# 9   https://t.co/2Wlxty6evj\nLawsuit says #Catholi...
# 10  The #pope's #apology in #Canada was #historic,...
# 11  Here are apologies popes have given for abuses...
# 12  Hmm? After meeting w #Pelosi #Pope delivers se...
# 13  😱Pope Francis &amp; the Omega Point???\n\nExpo...
# 14  ‘Peter himself can fail and become Satan’: How...
# 15  #president #zelensky held talks with #pope #fr...
# 16  Pope Francis looking fresh this morning.\n\nCh...
# 17  .@CanadianPM @JustinTrudeau traveled to the Va...
# 18  Pope Francis meets transgender guests of Rome ...
# 19  Cardinal Luis Antonio Tagle will be the next P...

# %% [markdown]
# ## Count recent 👀
#
# - Obtén el numero de tweets recientes de los ultimos 7 dias

# %%
#documentacion del endpoint https://developer.twitter.com/en/docs/twitter-api/tweets/counts/api-reference/get-tweets-counts-recent
#recent

# %%
query = "pope+francis"

tweets_recent = api.search(
                   q=query,
                   lang="en",
                   start_time='2022-08-10')
                   
print(f'Número de tweets recientes de los últimos 7 dias: {len(tweets_recent)}')
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-23-d84a3f3f22b7> in <module>
#       4                    q=query,
#       5                    lang="en",
# ----> 6                    start_time='2022-08-10'
#       7                    )
#       8
#
# /usr/local/lib/python3.7/dist-packages/tweepy/binder.py in _call(*args, **kwargs)
#     251                 return method
#     252             else:
# --> 253                 return method.execute()
#     254         finally:
#     255             method.session.close()
#
# /usr/local/lib/python3.7/dist-packages/tweepy/binder.py in execute(self)
#     232                     raise RateLimitError(error_msg, resp)
#     233                 else:
# --> 234                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     235
#     236             # Parse the response payload
#
# TweepError: [{'code': 89, 'message': 'Invalid or expired token.'}]
